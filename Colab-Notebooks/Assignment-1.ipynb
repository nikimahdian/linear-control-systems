# %% [markdown]
# <a href="https://colab.research.google.com/github/nikimahdian/linear-control-systems/blob/main/Colab-Notebooks/Assignment-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
import control as ctl

# !pip install control

# %%
#Example: G(s) = 10 / (s^2 + 2s + 1)
num = [10]
den = [1, 2, 1]
G = ctl.TransferFunction(num, den)
#Bode plot
plt.figure(figsize=(10, 6))
ctl.bode_plot(G, dB=True, Hz=False, deg=True)
plt.show()
#Nyquist plot
plt.figure(figsize=(8, 8))
ctl.nyquist_plot(G)
plt.grid()
plt.show()
